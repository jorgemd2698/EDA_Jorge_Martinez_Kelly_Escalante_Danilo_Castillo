# %%
import pandas as pd
df_datos = pd.read_csv("/Users/danilocastillo/Desktop/EDA_Jorge_Martinez_Kelly_Escalante_Danilo_Castillo/Data_sets/licencias_2024_limpio_P.csv")
import matplotlib.pyplot as plt

df_datos.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18915 entries, 0 to 18914
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   sexo                           18915 non-null  object
#  1   fechanacimiento                18915 non-null  object
#  2   descripcionprovinciadomicilio  18915 non-null  object
#  3   estado                         18915 non-null  int64
#  4   fechaaltasolicitud             18915 non-null  object
#  5   temporada                      18915 non-null  int64
#  6   modalidad                      18915 non-null  object
#  7   categoria                      18915 non-null  object
#  8   complementos                   5080 non-null   object
#  9   importeseguro                  18915 non-null  float64
#  10  cuota_socio                    18915 non-null  int64
#  11  nsocio                         18915 non-null  int64
# ...

# %%
df_datos.edad.hist()
# Out:
# <Axes: >

# %%
df_datos.discapacidad.value_counts()
# Out:
# discapacidad
# NO                                                      18873
# 65% sordera                                                 5
# 34% Permanente. doble trasplante (hepatorenal)              1
# 82% Visual y Movilidad                                      1
# 41% Física                                                  1
# 75% sordera                                                 1
# 85% Visual                                                  1
# 77% Visual                                                  1
# 65% Persona sorda auditiva                                  1
# 35% Psicosocial                                             1
# 67% Sordo                                                   1
# 51% Permanente                                              1
# 62% Sordo                                                   1
# 84% Visual                                                  1
# 33% permanente absoluta                                     1
# ...

# %%
df_datos["sexo"].value_counts()
# Out:
# sexo
# MASCULINO    12677
# FEMENINO      6238
# Name: count, dtype: int64

# %%
df_datos['sexo'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(6, 6)
)
# Out:
# <Axes: ylabel='count'>

# %%
# CARDINALIDAD

# cardinalidad_IC = len(df_datos["Categoria_IC"].unique())/len(df_datos)*100 print(cardinalidad_IC)

df_datos.head (10)
# Out:
#         sexo fechanacimiento descripcionprovinciadomicilio  estado  \
# 0  MASCULINO      1993-01-26                   GUADALAJARA       3
# 1   FEMENINO      1990-03-08                    VALLADOLID       3
# 2   FEMENINO      2013-04-26                        MADRID       3
# 3  MASCULINO      1936-07-30                        MADRID       3
# 4  MASCULINO      1946-12-16                        MADRID       3
# 5  MASCULINO      1990-10-24                        MADRID       3
# 6  MASCULINO      1981-01-26                        MADRID       3
# 7  MASCULINO      1972-04-12                        MADRID       3
# 8   FEMENINO      1957-06-19                        MADRID       3
# 9   FEMENINO      1946-03-04                        MADRID       3
#
#   fechaaltasolicitud  temporada modalidad       categoria complementos  \
# 0         2024-07-26       2024         C     Mayor Varón          NaN
# 1         2024-01-07       2024         B     Mayor Mujer        FEDME
# ...

# %%
df_datos['modalidad'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    figsize=(8, 8)
)
# Out:
# <Axes: ylabel='count'>
